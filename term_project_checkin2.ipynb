# %%
import pandas as pd
import requests as rq
house_prediction_data_url = 'https://raw.githubusercontent.com/bursteinalan/Data-Sets/master/Housing/House%20Prediction%20Data.csv'
r = rq.get(house_prediction_data_url)
fo = open('Term_Project_kdgarg_ksapra/house_prediction_data.csv', 'wb')
fo.write(r.content)
fo.close()

# %%
data_description_url = 'https://raw.githubusercontent.com/bursteinalan/Data-Sets/master/Housing/data_description.txt'
r2 = rq.get(data_description_url)
fo = open('Term_Project_kdgarg_ksapra/data_description.txt', 'wb')
fo.write(r2.content)
fo.close()

# %%
df = pd.read_csv('Term_Project_kdgarg_ksapra/house_prediction_data.csv')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 2914  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2915  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2916  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2917  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2918  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0            Lvl    AllPub  ...           0        0    NaN    NaN
# 1            Lvl    AllPub  ...           0        0    NaN    NaN
# 2            Lvl    AllPub  ...           0        0    NaN    NaN
# 3            Lvl    AllPub  ...           0        0    NaN    NaN
# 4            Lvl    AllPub  ...           0        0    NaN    NaN
# ...          ...       ...  ...         ...      ...    ...    ...
# 2914         Lvl    AllPub  ...           0        0    NaN    NaN
# 2915         Lvl    AllPub  ...           0        0    NaN    NaN
# 2916         Lvl    AllPub  ...           0        0    NaN    NaN
# 2917         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 2918         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SalePrice
# 0            NaN       0      2    2008        WD   208500.0
# 1            NaN       0      5    2007        WD   181500.0
# 2            NaN       0      9    2008        WD   223500.0
# 3            NaN       0      2    2006        WD   140000.0
# 4            NaN       0     12    2008        WD   250000.0
# ...          ...     ...    ...     ...       ...        ...
# 2914         NaN       0      6    2006        WD        NaN
# 2915         NaN       0      4    2006        WD        NaN
# 2916         NaN       0      9    2006        WD        NaN
# 2917        Shed     700      7    2006        WD        NaN
# 2918         NaN       0     11    2006        WD        NaN
#
# [2919 rows x 80 columns]

# %%
df.dtypes
# Out:
# Id               int64
# MSSubClass       int64
# MSZoning        object
# LotFrontage    float64
# LotArea          int64
#                 ...
# MiscVal          int64
# MoSold           int64
# YrSold           int64
# SaleType        object
# SalePrice      float64
# Length: 80, dtype: object

# %%
df.LotArea
# Out:
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
#         ...
# 2914     1936
# 2915     1894
# 2916    20000
# 2917    10441
# 2918     9627
# Name: LotArea, Length: 2919, dtype: int64
